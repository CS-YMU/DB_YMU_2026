# %%
-- =====================================================
-- Week04 Theory: 数据库完整性实验库
-- 适用于 MySQL 8
-- =====================================================

-- 1. 创建数据库
DROP DATABASE IF EXISTS week04_theory;
CREATE DATABASE week04_theory
CHARACTER SET utf8mb4
COLLATE utf8mb4_unicode_ci;

-- 2. 使用数据库
USE week04_theory;

-- =====================================================
-- 3. 学生表 Student
-- 演示：
-- PRIMARY KEY / NOT NULL / CHECK / DEFAULT
-- =====================================================
CREATE TABLE Student (
    ID VARCHAR(20) NOT NULL COMMENT '学号',
    Name VARCHAR(50) NOT NULL COMMENT '姓名',
    Sex ENUM('男', '女') NOT NULL COMMENT '性别',
    Age INT DEFAULT 18 COMMENT '年龄',
    Dept VARCHAR(50) NOT NULL COMMENT '院系',
    PRIMARY KEY (ID),
    CHECK (Age >= 15 AND Age <= 100)
) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='学生表';

-- =====================================================
-- 4. 课程表 Course
-- 演示：
-- PRIMARY KEY / UNIQUE / CHECK
-- =====================================================
CREATE TABLE Course (
    CourseID VARCHAR(10) NOT NULL COMMENT '课程号',
    CourseName VARCHAR(100) NOT NULL COMMENT '课程名',
    Credit INT NOT NULL DEFAULT 2 COMMENT '学分',
    Teacher VARCHAR(50) COMMENT '任课教师',
    PRIMARY KEY (CourseID),
    UNIQUE (CourseName),
    CHECK (Credit >= 1 AND Credit <= 10)
) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='课程表';

-- =====================================================
-- 5. 选课表 SC
-- 演示：
-- 复合主键 / 外键 / CHECK / CASCADE
-- =====================================================
CREATE TABLE SC (
    StudentID VARCHAR(20) NOT NULL COMMENT '学号',
    CourseID VARCHAR(10) NOT NULL COMMENT '课程号',
    Grade INT COMMENT '成绩',
    PRIMARY KEY (StudentID, CourseID),
    FOREIGN KEY (StudentID)
        REFERENCES Student(ID)
        ON DELETE CASCADE
        ON UPDATE CASCADE,
    FOREIGN KEY (CourseID)
        REFERENCES Course(CourseID)
        ON DELETE CASCADE
        ON UPDATE CASCADE,
    CHECK (Grade IS NULL OR (Grade >= 0 AND Grade <= 100))
) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='选课表';

-- =====================================================
-- 6. 班级表 Class
-- 演示：
-- 主键 / 唯一 / 非空
-- =====================================================
CREATE TABLE Class (
    ClassID VARCHAR(10) NOT NULL COMMENT '班级编号',
    ClassName VARCHAR(50) NOT NULL COMMENT '班级名称',
    GradeYear INT NOT NULL COMMENT '年级',
    PRIMARY KEY (ClassID),
    UNIQUE (ClassName),
    CHECK (GradeYear >= 2020 AND GradeYear <= 2100)
) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='班级表';

-- =====================================================
-- 7. 学生班级关系表 StudentClass
-- 演示：
-- 外键 / RESTRICT
-- =====================================================
CREATE TABLE StudentClass (
    StudentID VARCHAR(20) NOT NULL COMMENT '学号',
    ClassID VARCHAR(10) NOT NULL COMMENT '班级编号',
    EnrollDate DATE NOT NULL COMMENT '入班日期',
    PRIMARY KEY (StudentID),
    FOREIGN KEY (StudentID)
        REFERENCES Student(ID)
        ON DELETE RESTRICT
        ON UPDATE CASCADE,
    FOREIGN KEY (ClassID)
        REFERENCES Class(ClassID)
        ON DELETE RESTRICT
        ON UPDATE CASCADE
) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='学生班级表';

-- =====================================================
-- 8. 系主任表 Advisor
-- 演示：
-- UNIQUE / NOT NULL
-- =====================================================
CREATE TABLE Advisor (
    AdvisorID VARCHAR(10) NOT NULL COMMENT '教师编号',
    AdvisorName VARCHAR(50) NOT NULL COMMENT '教师姓名',
    Phone VARCHAR(20) UNIQUE COMMENT '电话',
    Dept VARCHAR(50) NOT NULL COMMENT '所属院系',
    PRIMARY KEY (AdvisorID)
) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='导师表';

-- =====================================================
-- 9. 学生导师表 StudentAdvisor
-- 演示：
-- SET NULL
-- =====================================================
CREATE TABLE StudentAdvisor (
    StudentID VARCHAR(20) NOT NULL COMMENT '学号',
    AdvisorID VARCHAR(10) COMMENT '导师编号',
    PRIMARY KEY (StudentID),
    FOREIGN KEY (StudentID)
        REFERENCES Student(ID)
        ON DELETE CASCADE
        ON UPDATE CASCADE,
    FOREIGN KEY (AdvisorID)
        REFERENCES Advisor(AdvisorID)
        ON DELETE SET NULL
        ON UPDATE CASCADE
) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='学生导师表';

-- =====================================================
-- 10. 宿舍表 Dormitory
-- 演示：
-- 主键 / 唯一 / CHECK
-- =====================================================
CREATE TABLE Dormitory (
    DormID VARCHAR(10) NOT NULL COMMENT '宿舍编号',
    Building VARCHAR(20) NOT NULL COMMENT '楼栋',
    RoomNo VARCHAR(20) NOT NULL COMMENT '房间号',
    Capacity INT NOT NULL DEFAULT 4 COMMENT '容量',
    PRIMARY KEY (DormID),
    UNIQUE (Building, RoomNo),
    CHECK (Capacity >= 1 AND Capacity <= 8)
) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='宿舍表';

-- =====================================================
-- 11. 学生住宿表 StudentDorm
-- 演示：
-- 一对一/多对一关系 / SET NULL
-- =====================================================
CREATE TABLE StudentDorm (
    StudentID VARCHAR(20) NOT NULL COMMENT '学号',
    DormID VARCHAR(10) COMMENT '宿舍编号',
    CheckInDate DATE,
    PRIMARY KEY (StudentID),
    FOREIGN KEY (StudentID)
        REFERENCES Student(ID)
        ON DELETE CASCADE
        ON UPDATE CASCADE,
    FOREIGN KEY (DormID)
        REFERENCES Dormitory(DormID)
        ON DELETE SET NULL
        ON UPDATE CASCADE
) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='学生住宿表';

-- =====================================================
-- 12. 插入测试数据
-- =====================================================

INSERT INTO Student (ID, Name, Sex, Age, Dept) VALUES
('2024001', '张三', '男', 19, 'CS'),
('2024002', '李四', '女', 20, 'CS'),
('2024003', '王五', '男', 18, 'MA'),
('2024004', '赵六', '女', 21, 'IS'),
('2024005', '钱七', '男', 22, 'EE');

INSERT INTO Course (CourseID, CourseName, Credit, Teacher) VALUES
('C001', '数据库原理', 4, '刘老师'),
('C002', '数据结构', 3, '王老师'),
('C003', '高等数学', 5, '陈老师'),
('C004', '计算机网络', 3, '张老师');

INSERT INTO SC (StudentID, CourseID, Grade) VALUES
('2024001', 'C001', 92),
('2024001', 'C002', 85),
('2024002', 'C001', 88),
('2024002', 'C004', 90),
('2024003', 'C003', 95),
('2024004', 'C002', 76),
('2024005', 'C004', 84);

INSERT INTO Class (ClassID, ClassName, GradeYear) VALUES
('CL01', '计算机241班', 2024),
('CL02', '数学241班', 2024),
('CL03', '信息241班', 2024);

INSERT INTO StudentClass (StudentID, ClassID, EnrollDate) VALUES
('2024001', 'CL01', '2024-09-01'),
('2024002', 'CL01', '2024-09-01'),
('2024003', 'CL02', '2024-09-01'),
('2024004', 'CL03', '2024-09-01'),
('2024005', 'CL03', '2024-09-01');

INSERT INTO Advisor (AdvisorID, AdvisorName, Phone, Dept) VALUES
('T001', '周老师', '13800000001', 'CS'),
('T002', '吴老师', '13800000002', 'MA'),
('T003', '郑老师', '13800000003', 'IS');

INSERT INTO StudentAdvisor (StudentID, AdvisorID) VALUES
('2024001', 'T001'),
('2024002', 'T001'),
('2024003', 'T002'),
('2024004', 'T003'),
('2024005', 'T003');

INSERT INTO Dormitory (DormID, Building, RoomNo, Capacity) VALUES
('D001', '1栋', '101', 4),
('D002', '1栋', '102', 4),
('D003', '2栋', '201', 6);

INSERT INTO StudentDorm (StudentID, DormID, CheckInDate) VALUES
('2024001', 'D001', '2024-09-02'),
('2024002', 'D001', '2024-09-02'),
('2024003', 'D002', '2024-09-02'),
('2024004', 'D003', '2024-09-02'),
('2024005', 'D003', '2024-09-02');

# %% [markdown]
# ---
#
# # 数据库实验课件（Week04）
#
# # 数据库完整性与数据更新
#
# ---
#
# # 第一部分 本章目标
#
# ## 第1页 学习目标
#
# 本章需要掌握：
#
# * 数据更新操作
#
#   ```text
#   INSERT / UPDATE / DELETE
#   ```
#
# * 数据库完整性的基本概念
#
#   ```text
#   数据正确性
#   数据有效性
#   数据一致性
#   ```
#
# * 三类完整性约束
#
#   ```text
#   实体完整性
#   参照完整性
#   用户定义完整性
#   ```
#
# * 典型外键动作
#
#   ```text
#   CASCADE
#   RESTRICT
#   SET NULL
#   ```
#
# ---
#
# # 第2页 本章实验数据库
#
# 数据库名称：
#
# ```text
# week04_theory
# ```
#
# 包含的表：
#
# ```text
# Student
# Course
# SC
# Class
# StudentClass
# Advisor
# StudentAdvisor
# Dormitory
# StudentDorm
# ```
#
# ---
#
# # 第二部分 创建数据库
#
# ## 第3页 创建数据库 SQL
#
# ```sql
# DROP DATABASE IF EXISTS week04_theory;
# CREATE DATABASE week04_theory
# CHARACTER SET utf8mb4
# COLLATE utf8mb4_unicode_ci;
#
# USE week04_theory;
# ```
#
# ---
#
# ## 第4页 解释
#
# ### 1. `DROP DATABASE IF EXISTS`
#
# 作用：
#
# ```text
# 如果数据库已经存在，则先删除，避免重复创建时报错
# ```
#
# ### 2. `CREATE DATABASE`
#
# 作用：
#
# ```text
# 创建新的实验数据库
# ```
#
# ### 3. `CHARACTER SET utf8mb4`
#
# 作用：
#
# ```text
# 支持中文、英文以及更完整的 Unicode 字符
# ```
#
# ### 4. `COLLATE utf8mb4_unicode_ci`
#
# 作用：
#
# ```text
# 指定字符比较规则，不区分大小写
# ```
#
# ---
#
# # 第三部分 Student 表：学生表
#
# ## 第5页 Student 表 SQL
#
# ```sql
# CREATE TABLE Student (
#     ID VARCHAR(20) NOT NULL COMMENT '学号',
#     Name VARCHAR(50) NOT NULL COMMENT '姓名',
#     Sex ENUM('男', '女') NOT NULL COMMENT '性别',
#     Age INT DEFAULT 18 COMMENT '年龄',
#     Dept VARCHAR(50) NOT NULL COMMENT '院系',
#     PRIMARY KEY (ID),
#     CHECK (Age >= 15 AND Age <= 100)
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='学生表';
# ```
#
# ---
#
# ## 第6页 Student 表中的约束
#
# ### 1. `ID VARCHAR(20) NOT NULL`
#
# 含义：
#
# ```text
# 学号不能为空
# ```
#
# ### 2. `PRIMARY KEY (ID)`
#
# 含义：
#
# ```text
# ID 是主键
# 必须唯一
# 不能重复
# 不能为 NULL
# ```
#
# ### 3. `Name VARCHAR(50) NOT NULL`
#
# 含义：
#
# ```text
# 姓名不能为空
# ```
#
# ### 4. `Sex ENUM('男','女') NOT NULL`
#
# 含义：
#
# ```text
# 性别只能取 男 或 女
# 同时不能为空
# ```
#
# ### 5. `Age INT DEFAULT 18`
#
# 含义：
#
# ```text
# 如果插入数据时没有写 Age，则默认值为 18
# ```
#
# ### 6. `CHECK (Age >= 15 AND Age <= 100)`
#
# 含义：
#
# ```text
# 年龄必须在 15 到 100 之间
# ```
#
# ---
#
# ## 第7页 Student 表约束详解
#
# ### 对应的完整性类型
#
# | 约束          | 类型      |
# | ----------- | ------- |
# | PRIMARY KEY | 实体完整性   |
# | NOT NULL    | 用户定义完整性 |
# | ENUM        | 用户定义完整性 |
# | DEFAULT     | 用户定义完整性 |
# | CHECK       | 用户定义完整性 |
#
# ---
#
# ## 第8页 Student 表正确插入示例
#
# ```sql
# INSERT INTO Student (ID, Name, Sex, Age, Dept)
# VALUES ('2024006', '孙八', '女', 19, 'CS');
# ```
#
# ---
#
# ## 第9页 Student 表错误示例
#
# ### 主键为空
#
# ```sql
# INSERT INTO Student (ID, Name, Sex, Age, Dept)
# VALUES (NULL, '测试', '男', 20, 'CS');
# ```
#
# 错误原因：
#
# ```text
# 违反主键和 NOT NULL 约束
# ```
#
# ### 年龄非法
#
# ```sql
# INSERT INTO Student (ID, Name, Sex, Age, Dept)
# VALUES ('2024999', '测试', '男', 200, 'CS');
# ```
#
# 错误原因：
#
# ```text
# 违反 CHECK (Age >= 15 AND Age <= 100)
# ```
#
# ### 性别非法
#
# ```sql
# INSERT INTO Student (ID, Name, Sex, Age, Dept)
# VALUES ('2024998', '测试', '未知', 20, 'CS');
# ```
#
# 错误原因：
#
# ```text
# ENUM 中不允许“未知”
# ```
#
# ---
#
# # 第四部分 Course 表：课程表
#
# ## 第10页 Course 表 SQL
#
# ```sql
# CREATE TABLE Course (
#     CourseID VARCHAR(10) NOT NULL COMMENT '课程号',
#     CourseName VARCHAR(100) NOT NULL COMMENT '课程名',
#     Credit INT NOT NULL DEFAULT 2 COMMENT '学分',
#     Teacher VARCHAR(50) COMMENT '任课教师',
#     PRIMARY KEY (CourseID),
#     UNIQUE (CourseName),
#     CHECK (Credit >= 1 AND Credit <= 10)
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='课程表';
# ```
#
# ---
#
# ## 第11页 Course 表中的约束
#
# ### 1. `CourseID NOT NULL`
#
# 含义：
#
# ```text
# 课程号不能为空
# ```
#
# ### 2. `PRIMARY KEY (CourseID)`
#
# 含义：
#
# ```text
# 课程号唯一，不能重复
# ```
#
# ### 3. `CourseName NOT NULL`
#
# 含义：
#
# ```text
# 课程名不能为空
# ```
#
# ### 4. `Credit INT NOT NULL DEFAULT 2`
#
# 含义：
#
# ```text
# 学分不能为空
# 如果不写，默认值为 2
# ```
#
# ### 5. `UNIQUE (CourseName)`
#
# 含义：
#
# ```text
# 课程名不能重复
# 例如不能同时存在两个“数据库原理”
# ```
#
# ### 6. `CHECK (Credit >= 1 AND Credit <= 10)`
#
# 含义：
#
# ```text
# 课程学分必须在 1 到 10 之间
# ```
#
# ---
#
# ## 第12页 Course 表约束详解
#
# | 约束          | 类型      |
# | ----------- | ------- |
# | PRIMARY KEY | 实体完整性   |
# | NOT NULL    | 用户定义完整性 |
# | UNIQUE      | 用户定义完整性 |
# | DEFAULT     | 用户定义完整性 |
# | CHECK       | 用户定义完整性 |
#
# ---
#
# ## 第13页 Course 表示例
#
# ### 正确插入
#
# ```sql
# INSERT INTO Course (CourseID, CourseName, Credit, Teacher)
# VALUES ('C005', '操作系统', 4, '李老师');
# ```
#
# ### 错误：课程名重复
#
# ```sql
# INSERT INTO Course (CourseID, CourseName, Credit, Teacher)
# VALUES ('C006', '数据库原理', 4, '王老师');
# ```
#
# 错误原因：
#
# ```text
# 违反 UNIQUE (CourseName)
# ```
#
# ### 错误：学分非法
#
# ```sql
# INSERT INTO Course (CourseID, CourseName, Credit, Teacher)
# VALUES ('C007', '人工智能', 20, '赵老师');
# ```
#
# 错误原因：
#
# ```text
# 违反 CHECK (Credit >= 1 AND Credit <= 10)
# ```
#
# ---
#
# # 第五部分 SC 表：选课表
#
# ## 第14页 SC 表 SQL
#
# ```sql
# CREATE TABLE SC (
#     StudentID VARCHAR(20) NOT NULL COMMENT '学号',
#     CourseID VARCHAR(10) NOT NULL COMMENT '课程号',
#     Grade INT COMMENT '成绩',
#     PRIMARY KEY (StudentID, CourseID),
#     FOREIGN KEY (StudentID)
#         REFERENCES Student(ID)
#         ON DELETE CASCADE
#         ON UPDATE CASCADE,
#     FOREIGN KEY (CourseID)
#         REFERENCES Course(CourseID)
#         ON DELETE CASCADE
#         ON UPDATE CASCADE,
#     CHECK (Grade IS NULL OR (Grade >= 0 AND Grade <= 100))
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='选课表';
# ```
#
# ---
#
# ## 第15页 SC 表中的约束
#
# ### 1. `PRIMARY KEY (StudentID, CourseID)`
#
# 含义：
#
# ```text
# 同一个学生同一门课只能出现一次
# 主键由两个字段共同组成，称为复合主键
# ```
#
# ### 2. `FOREIGN KEY (StudentID) REFERENCES Student(ID)`
#
# 含义：
#
# ```text
# 选课表中的 StudentID 必须来自 Student 表中已存在的学号
# ```
#
# ### 3. `FOREIGN KEY (CourseID) REFERENCES Course(CourseID)`
#
# 含义：
#
# ```text
# 选课表中的 CourseID 必须来自 Course 表中已存在的课程号
# ```
#
# ### 4. `ON DELETE CASCADE`
#
# 含义：
#
# ```text
# 如果主表中的学生或课程被删除，
# 则选课表中相关记录自动删除
# ```
#
# ### 5. `ON UPDATE CASCADE`
#
# 含义：
#
# ```text
# 如果主表中的主键值被修改，
# 则选课表中的外键值自动同步更新
# ```
#
# ### 6. `CHECK (Grade IS NULL OR (Grade >= 0 AND Grade <= 100))`
#
# 含义：
#
# ```text
# 成绩可以为空
# 如果不为空，则必须在 0 到 100 之间
# ```
#
# ---
#
# ## 第16页 SC 表约束详解
#
# | 约束           | 类型      |
# | ------------ | ------- |
# | 复合主键         | 实体完整性   |
# | 外键 StudentID | 参照完整性   |
# | 外键 CourseID  | 参照完整性   |
# | CHECK Grade  | 用户定义完整性 |
# | CASCADE      | 外键动作    |
#
# ---
#
# ## 第17页 SC 表正确插入示例
#
# ```sql
# INSERT INTO SC (StudentID, CourseID, Grade)
# VALUES ('2024001', 'C003', 88);
# ```
#
# ---
#
# ## 第18页 SC 表错误示例
#
# ### 错误：学生不存在
#
# ```sql
# INSERT INTO SC (StudentID, CourseID, Grade)
# VALUES ('999999', 'C001', 80);
# ```
#
# 错误原因：
#
# ```text
# 违反外键 StudentID → Student(ID)
# ```
#
# ### 错误：课程不存在
#
# ```sql
# INSERT INTO SC (StudentID, CourseID, Grade)
# VALUES ('2024001', 'C999', 80);
# ```
#
# 错误原因：
#
# ```text
# 违反外键 CourseID → Course(CourseID)
# ```
#
# ### 错误：成绩非法
#
# ```sql
# INSERT INTO SC (StudentID, CourseID, Grade)
# VALUES ('2024001', 'C001', 150);
# ```
#
# 错误原因：
#
# ```text
# 违反 CHECK，成绩必须在 0~100
# ```
#
# ### 错误：重复选课
#
# ```sql
# INSERT INTO SC (StudentID, CourseID, Grade)
# VALUES ('2024001', 'C001', 92);
# ```
#
# 错误原因：
#
# ```text
# 违反复合主键 (StudentID, CourseID)
# ```
#
# ---
#
# ## 第19页 CASCADE 演示
#
# ```sql
# DELETE FROM Student
# WHERE ID = '2024001';
# ```
#
# 结果：
#
# ```text
# Student 表中 2024001 被删除
# SC 表中该学生的所有选课记录也会自动删除
# ```
#
# ---
#
# ## 第20页 CASCADE 更新演示
#
# ```sql
# UPDATE Course
# SET CourseID = 'C101'
# WHERE CourseID = 'C001';
# ```
#
# 结果：
#
# ```text
# Course 表中课程号改变
# SC 表中对应的 CourseID 也会自动同步改为 C101
# ```
#
# ---
#
# # 第六部分 Class 表：班级表
#
# ## 第21页 Class 表 SQL
#
# ```sql
# CREATE TABLE Class (
#     ClassID VARCHAR(10) NOT NULL COMMENT '班级编号',
#     ClassName VARCHAR(50) NOT NULL COMMENT '班级名称',
#     GradeYear INT NOT NULL COMMENT '年级',
#     PRIMARY KEY (ClassID),
#     UNIQUE (ClassName),
#     CHECK (GradeYear >= 2020 AND GradeYear <= 2100)
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='班级表';
# ```
#
# ---
#
# ## 第22页 Class 表中的约束
#
# ### 1. `PRIMARY KEY (ClassID)`
#
# 含义：
#
# ```text
# 班级编号唯一
# ```
#
# ### 2. `UNIQUE (ClassName)`
#
# 含义：
#
# ```text
# 班级名称不能重复
# ```
#
# ### 3. `CHECK (GradeYear >= 2020 AND GradeYear <= 2100)`
#
# 含义：
#
# ```text
# 年级必须在合理范围内
# ```
#
# ---
#
# ## 第23页 Class 表示例
#
# ### 正确插入
#
# ```sql
# INSERT INTO Class (ClassID, ClassName, GradeYear)
# VALUES ('CL04', '电子241班', 2024);
# ```
#
# ### 错误：班级名重复
#
# ```sql
# INSERT INTO Class (ClassID, ClassName, GradeYear)
# VALUES ('CL05', '计算机241班', 2024);
# ```
#
# ### 错误：年级非法
#
# ```sql
# INSERT INTO Class (ClassID, ClassName, GradeYear)
# VALUES ('CL06', '测试班', 1800);
# ```
#
# ---
#
# # 第七部分 StudentClass 表：学生班级表
#
# ## 第24页 StudentClass 表 SQL
#
# ```sql
# CREATE TABLE StudentClass (
#     StudentID VARCHAR(20) NOT NULL COMMENT '学号',
#     ClassID VARCHAR(10) NOT NULL COMMENT '班级编号',
#     EnrollDate DATE NOT NULL COMMENT '入班日期',
#     PRIMARY KEY (StudentID),
#     FOREIGN KEY (StudentID)
#         REFERENCES Student(ID)
#         ON DELETE RESTRICT
#         ON UPDATE CASCADE,
#     FOREIGN KEY (ClassID)
#         REFERENCES Class(ClassID)
#         ON DELETE RESTRICT
#         ON UPDATE CASCADE
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='学生班级表';
# ```
#
# ---
#
# ## 第25页 StudentClass 表中的约束
#
# ### 1. `PRIMARY KEY (StudentID)`
#
# 含义：
#
# ```text
# 每个学生在 StudentClass 表中只能出现一次
# 即每个学生只能属于一个班级
# ```
#
# ### 2. `FOREIGN KEY (StudentID) REFERENCES Student(ID)`
#
# 含义：
#
# ```text
# StudentClass 中的 StudentID 必须来自 Student 表
# ```
#
# ### 3. `FOREIGN KEY (ClassID) REFERENCES Class(ClassID)`
#
# 含义：
#
# ```text
# StudentClass 中的 ClassID 必须来自 Class 表
# ```
#
# ### 4. `ON DELETE RESTRICT`
#
# 含义：
#
# ```text
# 如果某学生或某班级已经被 StudentClass 引用，
# 则不允许直接删除主表中的对应记录
# ```
#
# ### 5. `EnrollDate DATE NOT NULL`
#
# 含义：
#
# ```text
# 入班日期不能为空
# ```
#
# ---
#
# ## 第26页 RESTRICT 演示
#
# ```sql
# DELETE FROM Class
# WHERE ClassID = 'CL01';
# ```
#
# 结果：
#
# ```text
# 删除失败
# 因为 StudentClass 中还有学生引用 CL01
# ```
#
# ---
#
# ## 第27页 StudentClass 表错误示例
#
# ### 错误：学生不存在
#
# ```sql
# INSERT INTO StudentClass (StudentID, ClassID, EnrollDate)
# VALUES ('999999', 'CL01', '2024-09-01');
# ```
#
# ### 错误：班级不存在
#
# ```sql
# INSERT INTO StudentClass (StudentID, ClassID, EnrollDate)
# VALUES ('2024001', 'CL99', '2024-09-01');
# ```
#
# ### 错误：学生重复分班
#
# ```sql
# INSERT INTO StudentClass (StudentID, ClassID, EnrollDate)
# VALUES ('2024001', 'CL02', '2024-09-10');
# ```
#
# 错误原因：
#
# ```text
# StudentID 是主键，一个学生只能出现一次
# ```
#
# ---
#
# # 第八部分 Advisor 表：导师表
#
# ## 第28页 Advisor 表 SQL
#
# ```sql
# CREATE TABLE Advisor (
#     AdvisorID VARCHAR(10) NOT NULL COMMENT '教师编号',
#     AdvisorName VARCHAR(50) NOT NULL COMMENT '教师姓名',
#     Phone VARCHAR(20) UNIQUE COMMENT '电话',
#     Dept VARCHAR(50) NOT NULL COMMENT '所属院系',
#     PRIMARY KEY (AdvisorID)
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='导师表';
# ```
#
# ---
#
# ## 第29页 Advisor 表中的约束
#
# ### 1. `PRIMARY KEY (AdvisorID)`
#
# 含义：
#
# ```text
# 教师编号唯一
# ```
#
# ### 2. `AdvisorName NOT NULL`
#
# 含义：
#
# ```text
# 教师姓名不能为空
# ```
#
# ### 3. `Phone UNIQUE`
#
# 含义：
#
# ```text
# 电话号码不能重复
# ```
#
# ### 4. `Dept NOT NULL`
#
# 含义：
#
# ```text
# 导师所属院系不能为空
# ```
#
# ---
#
# ## 第30页 Advisor 表示例
#
# ### 正确插入
#
# ```sql
# INSERT INTO Advisor (AdvisorID, AdvisorName, Phone, Dept)
# VALUES ('T004', '孙老师', '13800000004', 'EE');
# ```
#
# ### 错误：电话重复
#
# ```sql
# INSERT INTO Advisor (AdvisorID, AdvisorName, Phone, Dept)
# VALUES ('T005', '周老师2', '13800000001', 'CS');
# ```
#
# ---
#
# # 第九部分 StudentAdvisor 表：学生导师表
#
# ## 第31页 StudentAdvisor 表 SQL
#
# ```sql
# CREATE TABLE StudentAdvisor (
#     StudentID VARCHAR(20) NOT NULL COMMENT '学号',
#     AdvisorID VARCHAR(10) COMMENT '导师编号',
#     PRIMARY KEY (StudentID),
#     FOREIGN KEY (StudentID)
#         REFERENCES Student(ID)
#         ON DELETE CASCADE
#         ON UPDATE CASCADE,
#     FOREIGN KEY (AdvisorID)
#         REFERENCES Advisor(AdvisorID)
#         ON DELETE SET NULL
#         ON UPDATE CASCADE
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='学生导师表';
# ```
#
# ---
#
# ## 第32页 StudentAdvisor 表中的约束
#
# ### 1. `PRIMARY KEY (StudentID)`
#
# 含义：
#
# ```text
# 每个学生在学生导师表中只出现一次
# 即一个学生只对应一个导师
# ```
#
# ### 2. `FOREIGN KEY (StudentID) ... ON DELETE CASCADE`
#
# 含义：
#
# ```text
# 删除学生时，学生导师关系自动删除
# ```
#
# ### 3. `FOREIGN KEY (AdvisorID) ... ON DELETE SET NULL`
#
# 含义：
#
# ```text
# 删除导师时，不删除学生记录
# 而是把学生对应的 AdvisorID 设为 NULL
# ```
#
# ---
#
# ## 第33页 SET NULL 演示
#
# ```sql
# DELETE FROM Advisor
# WHERE AdvisorID = 'T001';
# ```
#
# 结果：
#
# ```text
# Advisor 表中 T001 被删除
# StudentAdvisor 表中原来引用 T001 的记录，AdvisorID 自动变为 NULL
# ```
#
# ---
#
# ## 第34页 StudentAdvisor 表错误示例
#
# ### 错误：导师不存在
#
# ```sql
# INSERT INTO StudentAdvisor (StudentID, AdvisorID)
# VALUES ('2024001', 'T999');
# ```
#
# ### 错误：学生不存在
#
# ```sql
# INSERT INTO StudentAdvisor (StudentID, AdvisorID)
# VALUES ('999999', 'T001');
# ```
#
# ---
#
# # 第十部分 Dormitory 表：宿舍表
#
# ## 第35页 Dormitory 表 SQL
#
# ```sql
# CREATE TABLE Dormitory (
#     DormID VARCHAR(10) NOT NULL COMMENT '宿舍编号',
#     Building VARCHAR(20) NOT NULL COMMENT '楼栋',
#     RoomNo VARCHAR(20) NOT NULL COMMENT '房间号',
#     Capacity INT NOT NULL DEFAULT 4 COMMENT '容量',
#     PRIMARY KEY (DormID),
#     UNIQUE (Building, RoomNo),
#     CHECK (Capacity >= 1 AND Capacity <= 8)
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='宿舍表';
# ```
#
# ---
#
# ## 第36页 Dormitory 表中的约束
#
# ### 1. `PRIMARY KEY (DormID)`
#
# 含义：
#
# ```text
# 宿舍编号唯一
# ```
#
# ### 2. `UNIQUE (Building, RoomNo)`
#
# 含义：
#
# ```text
# 同一栋楼中，房间号不能重复
# 这是组合唯一约束
# ```
#
# ### 3. `Capacity INT NOT NULL DEFAULT 4`
#
# 含义：
#
# ```text
# 宿舍容量不能为空，默认是 4 人
# ```
#
# ### 4. `CHECK (Capacity >= 1 AND Capacity <= 8)`
#
# 含义：
#
# ```text
# 宿舍容量必须在 1 到 8 之间
# ```
#
# ---
#
# ## 第37页 Dormitory 表示例
#
# ### 正确插入
#
# ```sql
# INSERT INTO Dormitory (DormID, Building, RoomNo, Capacity)
# VALUES ('D004', '3栋', '301', 4);
# ```
#
# ### 错误：同楼栋房间重复
#
# ```sql
# INSERT INTO Dormitory (DormID, Building, RoomNo, Capacity)
# VALUES ('D005', '1栋', '101', 4);
# ```
#
# ### 错误：容量非法
#
# ```sql
# INSERT INTO Dormitory (DormID, Building, RoomNo, Capacity)
# VALUES ('D006', '3栋', '302', 20);
# ```
#
# ---
#
# # 第十一部分 StudentDorm 表：学生住宿表
#
# ## 第38页 StudentDorm 表 SQL
#
# ```sql
# CREATE TABLE StudentDorm (
#     StudentID VARCHAR(20) NOT NULL COMMENT '学号',
#     DormID VARCHAR(10) COMMENT '宿舍编号',
#     CheckInDate DATE,
#     PRIMARY KEY (StudentID),
#     FOREIGN KEY (StudentID)
#         REFERENCES Student(ID)
#         ON DELETE CASCADE
#         ON UPDATE CASCADE,
#     FOREIGN KEY (DormID)
#         REFERENCES Dormitory(DormID)
#         ON DELETE SET NULL
#         ON UPDATE CASCADE
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COMMENT='学生住宿表';
# ```
#
# ---
#
# ## 第39页 StudentDorm 表中的约束
#
# ### 1. `PRIMARY KEY (StudentID)`
#
# 含义：
#
# ```text
# 每个学生在住宿表中只能出现一次
# 即每个学生当前只有一个宿舍记录
# ```
#
# ### 2. `FOREIGN KEY (StudentID) ... ON DELETE CASCADE`
#
# 含义：
#
# ```text
# 删除学生时，住宿信息自动删除
# ```
#
# ### 3. `FOREIGN KEY (DormID) ... ON DELETE SET NULL`
#
# 含义：
#
# ```text
# 删除宿舍时，不删除学生住宿记录
# 而是将 DormID 设为 NULL
# ```
#
# ---
#
# ## 第40页 StudentDorm 表示例
#
# ### 删除宿舍
#
# ```sql
# DELETE FROM Dormitory
# WHERE DormID = 'D001';
# ```
#
# 结果：
#
# ```text
# StudentDorm 中原来住 D001 的学生记录仍保留
# 但 DormID 变为 NULL
# ```
#
# ---
#
# # 第十二部分 测试数据插入
#
# ## 第41页 插入 Student 数据
#
# ```sql
# INSERT INTO Student (ID, Name, Sex, Age, Dept) VALUES
# ('2024001', '张三', '男', 19, 'CS'),
# ('2024002', '李四', '女', 20, 'CS'),
# ('2024003', '王五', '男', 18, 'MA'),
# ('2024004', '赵六', '女', 21, 'IS'),
# ('2024005', '钱七', '男', 22, 'EE');
# ```
#
# ---
#
# ## 第42页 插入 Course 数据
#
# ```sql
# INSERT INTO Course (CourseID, CourseName, Credit, Teacher) VALUES
# ('C001', '数据库原理', 4, '刘老师'),
# ('C002', '数据结构', 3, '王老师'),
# ('C003', '高等数学', 5, '陈老师'),
# ('C004', '计算机网络', 3, '张老师');
# ```
#
# ---
#
# ## 第43页 插入 SC 数据
#
# ```sql
# INSERT INTO SC (StudentID, CourseID, Grade) VALUES
# ('2024001', 'C001', 92),
# ('2024001', 'C002', 85),
# ('2024002', 'C001', 88),
# ('2024002', 'C004', 90),
# ('2024003', 'C003', 95),
# ('2024004', 'C002', 76),
# ('2024005', 'C004', 84);
# ```
#
# ---
#
# ## 第44页 插入 Class 与 StudentClass 数据
#
# ```sql
# INSERT INTO Class (ClassID, ClassName, GradeYear) VALUES
# ('CL01', '计算机241班', 2024),
# ('CL02', '数学241班', 2024),
# ('CL03', '信息241班', 2024);
#
# INSERT INTO StudentClass (StudentID, ClassID, EnrollDate) VALUES
# ('2024001', 'CL01', '2024-09-01'),
# ('2024002', 'CL01', '2024-09-01'),
# ('2024003', 'CL02', '2024-09-01'),
# ('2024004', 'CL03', '2024-09-01'),
# ('2024005', 'CL03', '2024-09-01');
# ```
#
# ---
#
# ## 第45页 插入 Advisor 与 StudentAdvisor 数据
#
# ```sql
# INSERT INTO Advisor (AdvisorID, AdvisorName, Phone, Dept) VALUES
# ('T001', '周老师', '13800000001', 'CS'),
# ('T002', '吴老师', '13800000002', 'MA'),
# ('T003', '郑老师', '13800000003', 'IS');
#
# INSERT INTO StudentAdvisor (StudentID, AdvisorID) VALUES
# ('2024001', 'T001'),
# ('2024002', 'T001'),
# ('2024003', 'T002'),
# ('2024004', 'T003'),
# ('2024005', 'T003');
# ```
#
# ---
#
# ## 第46页 插入 Dormitory 与 StudentDorm 数据
#
# ```sql
# INSERT INTO Dormitory (DormID, Building, RoomNo, Capacity) VALUES
# ('D001', '1栋', '101', 4),
# ('D002', '1栋', '102', 4),
# ('D003', '2栋', '201', 6);
#
# INSERT INTO StudentDorm (StudentID, DormID, CheckInDate) VALUES
# ('2024001', 'D001', '2024-09-02'),
# ('2024002', 'D001', '2024-09-02'),
# ('2024003', 'D002', '2024-09-02'),
# ('2024004', 'D003', '2024-09-02'),
# ('2024005', 'D003', '2024-09-02');
# ```
#
# ---
#
# # 第十三部分 数据更新操作
#
# ## 第47页 INSERT
#
# ```sql
# INSERT INTO Student (ID, Name, Sex, Age, Dept)
# VALUES ('2024006', '测试学生', '男', 20, 'CS');
# ```
#
# 说明：
#
# ```text
# 向 Student 表中插入一条新记录
# ```
#
# ---
#
# ## 第48页 UPDATE
#
# ```sql
# UPDATE Student
# SET Age = 21
# WHERE ID = '2024001';
# ```
#
# 说明：
#
# ```text
# 将 2024001 的年龄更新为 21
# ```
#
# ---
#
# ## 第49页 DELETE
#
# ```sql
# DELETE FROM Student
# WHERE ID = '2024001';
# ```
#
# 说明：
#
# ```text
# 删除该学生
# 并触发与之相关的外键动作
# ```
#
# ---
#
# ## 第50页 危险操作提醒
#
# ```sql
# DELETE FROM Student;
# ```
#
# 说明：
#
# ```text
# 删除 Student 表中的所有记录
# ```
#
# ⚠️ 注意：
#
# ```text
# 如果存在 CASCADE，相关子表数据也可能联动删除
# ```
#
# ---
#
# # 第十四部分 三大完整性总结
#
# ## 第51页 三大完整性
#
# | 完整性类型   | 含义          | 本章示例                                                 |
# | ------- | ----------- | ---------------------------------------------------- |
# | 实体完整性   | 主键唯一且非空     | Student.ID, Course.CourseID, SC(StudentID, CourseID) |
# | 参照完整性   | 外键必须引用已存在数据 | SC.StudentID → Student.ID                            |
# | 用户定义完整性 | 满足业务规则      | Age 范围、Credit 范围、Phone 唯一                            |
#
# ---
#
# ## 第52页 各表约束总览
#
# | 表名             | 主要约束                                          |
# | -------------- | --------------------------------------------- |
# | Student        | PRIMARY KEY, NOT NULL, DEFAULT, CHECK, ENUM   |
# | Course         | PRIMARY KEY, UNIQUE, NOT NULL, DEFAULT, CHECK |
# | SC             | 复合主键, 外键, CHECK, CASCADE                      |
# | Class          | PRIMARY KEY, UNIQUE, CHECK                    |
# | StudentClass   | PRIMARY KEY, 外键, RESTRICT                     |
# | Advisor        | PRIMARY KEY, UNIQUE, NOT NULL                 |
# | StudentAdvisor | PRIMARY KEY, 外键, SET NULL, CASCADE            |
# | Dormitory      | PRIMARY KEY, 组合 UNIQUE, DEFAULT, CHECK        |
# | StudentDorm    | PRIMARY KEY, 外键, SET NULL, CASCADE            |
#
# ---
#
# ## 第53页 外键动作对比
#
# | 动作       | 含义                   |
# | -------- | -------------------- |
# | CASCADE  | 主表删除/更新时，子表自动同步删除/更新 |
# | RESTRICT | 如果子表正在引用，则拒绝删除/更新    |
# | SET NULL | 主表删除时，将子表外键置为 NULL   |
#
# ---
#
# ## 第54页 本章重点
#
# 需要掌握：
#
# ```text
# PRIMARY KEY
# FOREIGN KEY
# NOT NULL
# UNIQUE
# DEFAULT
# CHECK
# CASCADE
# RESTRICT
# SET NULL
# INSERT / UPDATE / DELETE
# ```
#
# ---
#
# ## 第55页 课堂口诀
#
# ```text
# 主键唯一不能空
# 外键引用要存在
# 业务规则自己定
# 级联限制要分清
# ```
#
# ---
