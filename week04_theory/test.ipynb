# %%
import pymysql
from tabulate import tabulate

# 数据库连接配置
config = {
    "host": "localhost",
    "user": "dylan",
    "password": "P@ssw0rd",
    "database": "week04_theory",
    "charset": "utf8mb4",
    "cursorclass": pymysql.cursors.DictCursor,
}

# 连接数据库
conn = pymysql.connect(**config)
cursor = conn.cursor()

# 执行查询：按院系和性别统计人数
cursor.execute("""
INSERT INTO Student (ID, Name, Sex, Dept)
VALUES ('2024008', '孙八', '女', 'CS');
""")

conn.commit() # 提交事务，在执行INSERT、UPDATE、DELETE等修改数据的操作后需要调用commit()方法来提交事务，否则修改不会生效。

results = cursor.fetchall()

if results:
    print(tabulate(results, headers="keys", tablefmt="grid"))
    print(f"\n总记录数: {len(results)} 条")
else:
    print("没有找到符合条件的数据")

cursor.close()
conn.close()
# Out:
# 没有找到符合条件的数据
