# %%
import pymysql
from tabulate import tabulate

# 数据库连接配置
config = {
    "host": "localhost",
    "user": "dylan",
    "password": "P@ssw0rd",
    "database": "db_experiment_week03",
    "charset": "utf8mb4",
    "cursorclass": pymysql.cursors.DictCursor,
}

# 连接数据库
conn = pymysql.connect(**config)
cursor = conn.cursor()

# 执行查询：按院系和性别统计人数
cursor.execute("""
SELECT *
FROM SC
RIGHT JOIN Course
ON SC.CourseID = Course.CourseID;
""")
results = cursor.fetchall()

if results:
    print(tabulate(results, headers="keys", tablefmt="grid"))
    print(f"\n总记录数: {len(results)} 条")
else:
    print("没有找到符合条件的数据")

cursor.close()
conn.close()
# Out:
# +-------------+------------+---------+-------------------+----------------+----------+
# |   StudentID | CourseID   |   Grade | Course.CourseID   | CourseName     |   Credit |
# +=============+============+=========+===================+================+==========+
# |   200215121 | C001       |      95 | C001              | 数据库系统概论 |        4 |
# +-------------+------------+---------+-------------------+----------------+----------+
# |   200215122 | C001       |      98 | C001              | 数据库系统概论 |        4 |
# +-------------+------------+---------+-------------------+----------------+----------+
# |   200215124 | C001       |      91 | C001              | 数据库系统概论 |        4 |
# +-------------+------------+---------+-------------------+----------------+----------+
# |   200215125 | C001       |      76 | C001              | 数据库系统概论 |        4 |
# +-------------+------------+---------+-------------------+----------------+----------+
# |   200215121 | C002       |      88 | C002              | 数据结构       |        3 |
# +-------------+------------+---------+-------------------+----------------+----------+
# |   200215123 | C002       |      78 | C002              | 数据结构       |        3 |
# +-------------+------------+---------+-------------------+----------------+----------+
# |   200215126 | C002       |      96 | C002              | 数据结构       |        3 |
# +-------------+------------+---------+-------------------+----------------+----------+
# |   200215121 | C003       |      92 | C003              | 高等数学       |        5 |
# +-------------+------------+---------+-------------------+----------------+----------+
# |   200215124 | C003       |      87 | C003              | 高等数学       |        5 |
# +-------------+------------+---------+-------------------+----------------+----------+
# |   200215122 | C004       |      85 | C004              | 计算机网络     |        3 |
# +-------------+------------+---------+-------------------+----------------+----------+
# |   200215125 | C004       |      94 | C004              | 计算机网络     |        3 |
# +-------------+------------+---------+-------------------+----------------+----------+
# |   200215123 | C005       |      82 | C005              | 操作系统       |        4 |
# +-------------+------------+---------+-------------------+----------------+----------+
# |   200215126 | C005       |      89 | C005              | 操作系统       |        4 |
# +-------------+------------+---------+-------------------+----------------+----------+
# |             |            |         | C006              | 人工智能导论   |        2 |
# +-------------+------------+---------+-------------------+----------------+----------+
#
# 总记录数: 14 条
